# %%
import pandas as pd

# %% [markdown]
# ## The `.groupby()` Method

# %%
fortune = pd.read_csv("data/fortune1000.csv", index_col = "Rank")
sectors = fortune.groupby("Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# ## Retrieve A Group with the `.get_group()` Method

# %%
fortune = pd.read_csv("data/fortune1000.csv", index_col = "Rank")
sectors = fortune.groupby("Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.get_group('Retailing')
# Out:
#                                Company     Sector  \
# Rank
# 1                              Walmart  Retailing
# 15                              Costco  Retailing
# 28                          Home Depot  Retailing
# 38                              Target  Retailing
# 47                              Lowe’s  Retailing
# 71                            Best Buy  Retailing
# 89                                 TJX  Retailing
# 103                             Macy’s  Retailing
# 111                     Sears Holdings  Retailing
# 132                            Staples  Retailing
# 136                         AutoNation  Retailing
# 139                     Dollar General  Retailing
# 143            Penske Automotive Group  Retailing
# 145                             Kohl’s  Retailing
# 177                                Gap  Retailing
# 180                        Dollar Tree  Retailing
# 191                             CarMax  Retailing
# 196                       Office Depot  Retailing
# ...

# %% [markdown]
# ## Methods on the Groupby Object and `DataFrame` Columns

# %%
fortune = pd.read_csv("data/fortune1000.csv", index_col = "Rank")
sectors = fortune.groupby("Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.get_group("Apparel")["Profits"]
# Out:
# Rank
# 91     3273
# 231    1232
# 340     572
# 354     702
# 448     429
# 547     209
# 575     402
# 597     233
# 683     221
# 695     232
# 726     238
# 794     123
# 877     114
# 882     174
# 917      82
# Name: Profits, dtype: int64

# %%
sectors.get_group("Apparel")["Profits"].sum()
# Out:
# 8236

# %%
# Maximum value in each group
sectors.max()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                         Woodward
# Apparel                         Wolverine World Wide
# Business Services                      Western Union
# Chemicals                          Westlake Chemical
# Energy                                   Xcel Energy
# Engineering & Construction              Tutor Perini
# Financials                            Zions Bancorp.
# Food and Drug Stores              Whole Foods Market
# Food, Beverages & Tobacco            WhiteWave Foods
# Health Care                          inVentiv Health
# Hotels, Resturants & Leisure              Yum Brands
# Household Products                     Vista Outdoor
# Industrials                       Zebra Technologies
# Materials                     Worthington Industries
# Media                                    iHeartMedia
# Motor Vehicles & Parts               Wabash National
# ...

# %%
#Minimum value in each group
sectors.min()
# Out:
#                                                     Company  \
# Sector
# Aerospace & Defense                           B/E Aerospace
# Apparel                                            Carter’s
# Business Services                            ABM Industries
# Chemicals                                       A. Schulman
# Energy                                                  AES
# Engineering & Construction                            AECOM
# Financials                                              AIG
# Food and Drug Stores                             CVS Health
# Food, Beverages & Tobacco        Alliance One International
# Health Care                                          AbbVie
# Hotels, Resturants & Leisure                Bloomin’ Brands
# Household Products                            Avon Products
# Industrials                                              3M
# Materials                            A-Mark Precious Metals
# ...

# %%
# sum of all values in each group
sectors.sum()
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
# Mean of all values in each group
print(sectors.mean())
# Out:
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# Chemicals                      8129.900000   754.266667  15455.033333
# Energy                        12441.057377  -602.024590   9745.303279
# Engineering & Construction     5922.423077   204.000000  15642.615385
# Financials                    15950.784173  1872.007194  24172.287770
# Food and Drug Stores          32251.266667  1117.266667  93026.533333
# Food, Beverages & Tobacco     12929.465116  1195.744186  28177.488372
# Health Care                   21529.426667  1414.853333  35710.520000
# Hotels, Resturants & Leisure   6781.840000   827.880000  99369.800000
# Household Products             8383.464286   515.285714  23072.785714
# ...

# %%
sectors["Revenue"].sum()
sectors["Employees"].sum()
sectors["Profits"].max()
sectors["Profits"].min()
sectors["Employees"].mean()

sectors[["Revenue", "Profits"]].sum()
# Out:
#                               Revenue  Profits
# Sector
# Aerospace & Defense            357940    28742
# Apparel                         95968     8236
# Business Services              272195    28227
# Chemicals                      243897    22628
# Energy                        1517809   -73447
# Engineering & Construction     153983     5304
# Financials                    2217159   260209
# Food and Drug Stores           483769    16759
# Food, Beverages & Tobacco      555967    51417
# Health Care                   1614707   106114
# Hotels, Resturants & Leisure   169546    20697
# Household Products             234737    14428
# Industrials                    497581    20764
# Materials                      259145     4428
# Media                          220764    24347
# Motor Vehicles & Parts         482540    25898
# Retailing                     1465076    47830
# Technology                    1377600   180473
# Telecommunications             461834    48637
# ...

# %% [markdown]
# ## Grouping by Multiple Columns

# %%
fortune = pd.read_csv("data/fortune1000.csv", index_col = "Rank")
sectors = fortune.groupby(["Sector", "Industry"])
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors.size()
sectors.sum()
sectors["Revenue"].sum()
sectors["Employees"].mean()
# Out:
# Sector                      Industry
# Aerospace & Defense         Aerospace and Defense                              48402.850000
# Apparel                     Apparel                                            23093.133333
# Business Services           Advertising, marketing                             62050.000000
#                             Diversified Outsourcing Services                   50595.000000
#                             Education                                          15585.000000
#                             Financial Data Services                            13943.473684
#                             Miscellaneous                                      12573.333333
#                             Temporary Help                                     12004.000000
#                             Waste Management                                   23839.800000
# Chemicals                   Chemicals                                          15455.033333
# ...

# %% [markdown]
# ## The `.agg()` Method

# %%
fortune = pd.read_csv("data/fortune1000.csv", index_col = "Rank")
sectors = fortune.groupby("Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
sectors["Employees"].mean()
# Out:
# Sector
# Aerospace & Defense             48402.850000
# Apparel                         23093.133333
# Business Services               26687.254902
# Chemicals                       15455.033333
# Energy                           9745.303279
# Engineering & Construction      15642.615385
# Financials                      24172.287770
# Food and Drug Stores            93026.533333
# Food, Beverages & Tobacco       28177.488372
# Health Care                     35710.520000
# Hotels, Resturants & Leisure    99369.800000
# Household Products              23072.785714
# Industrials                     33591.934783
# Materials                       14840.069767
# Media                           22012.560000
# Motor Vehicles & Parts          45106.666667
# Retailing                       77845.362500
# Technology                      35087.735294
# Telecommunications              55497.866667
# Transportation                  42688.694444
# Wholesalers                     13139.925000
# ...

# %%
sectors.agg({"Revenue" : ["sum", "mean"],
             "Profits" : "sum",
              "Employees" : "mean"})
# Out:
#                               Revenue               Profits     Employees
#                                   sum          mean     sum          mean
# Sector
# Aerospace & Defense            357940  17897.000000   28742  48402.850000
# Apparel                         95968   6397.866667    8236  23093.133333
# Business Services              272195   5337.156863   28227  26687.254902
# Chemicals                      243897   8129.900000   22628  15455.033333
# Energy                        1517809  12441.057377  -73447   9745.303279
# Engineering & Construction     153983   5922.423077    5304  15642.615385
# Financials                    2217159  15950.784173  260209  24172.287770
# Food and Drug Stores           483769  32251.266667   16759  93026.533333
# Food, Beverages & Tobacco      555967  12929.465116   51417  28177.488372
# Health Care                   1614707  21529.426667  106114  35710.520000
# Hotels, Resturants & Leisure   169546   6781.840000   20697  99369.800000
# ...

# %%
sectors.agg(["size", "sum", "mean"])
# Out:
#                              Revenue                        Profits          \
#                                 size      sum          mean    size     sum
# Sector
# Aerospace & Defense               20   357940  17897.000000      20   28742
# Apparel                           15    95968   6397.866667      15    8236
# Business Services                 51   272195   5337.156863      51   28227
# Chemicals                         30   243897   8129.900000      30   22628
# Energy                           122  1517809  12441.057377     122  -73447
# Engineering & Construction        26   153983   5922.423077      26    5304
# Financials                       139  2217159  15950.784173     139  260209
# Food and Drug Stores              15   483769  32251.266667      15   16759
# Food, Beverages & Tobacco         43   555967  12929.465116      43   51417
# Health Care                       75  1614707  21529.426667      75  106114
# ...

# %% [markdown]
# ## Iterating through Groups

# %%
fortune = pd.read_csv("data/fortune1000.csv", index_col = "Rank")
sectors = fortune.groupby("Sector")
fortune.head(3)
# Out:
#           Company      Sector                     Industry         Location  \
# Rank
# 1         Walmart   Retailing        General Merchandisers  Bentonville, AR
# 2     Exxon Mobil      Energy           Petroleum Refining       Irving, TX
# 3           Apple  Technology  Computers, Office Equipment    Cupertino, CA
#
#       Revenue  Profits  Employees
# Rank
# 1      482130    14694    2300000
# 2      246204    16150      75600
# 3      233715    53394     110000

# %%
df = pd.DataFrame(columns = fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for sector, data in sectors:
    highest_revenue_company_in_group = data.nlargest(1, "Revenue")
    df = df.append(highest_revenue_company_in_group)

# %%
df
# Out:
#                     Company                        Sector  \
# 24                   Boeing           Aerospace & Defense
# 91                     Nike                       Apparel
# 144           ManpowerGroup             Business Services
# 56             Dow Chemical                     Chemicals
# 2               Exxon Mobil                        Energy
# 155                   Fluor    Engineering & Construction
# 4        Berkshire Hathaway                    Financials
# 7                CVS Health          Food and Drug Stores
# 41   Archer Daniels Midland     Food, Beverages & Tobacco
# 5                  McKesson                   Health Care
# 109              McDonald’s  Hotels, Resturants & Leisure
# 34         Procter & Gamble            Household Products
# 11         General Electric                   Industrials
# 126                   Alcoa                     Materials
# 53                   Disney                         Media
# ...

# %%
cities = fortune.groupby("Location")
df = pd.DataFrame(columns = fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for city, data in cities:
    highest_revenue_in_city = data.nlargest(1, "Revenue")
    df = df.append(highest_revenue_in_city)

# %%
df
# Out:
#                                   Company                        Sector  \
# 138                   Abbott Laboratories                   Health Care
# 169                Goodyear Tire & Rubber        Motor Vehicles & Parts
# 288              Air Products & Chemicals                     Chemicals
# 830                 Benchmark Electronics                    Technology
# 374                Casey’s General Stores                     Retailing
# 915                        Domino’s Pizza  Hotels, Resturants & Leisure
# 596                                Colfax                   Industrials
# 215                          Land O’Lakes     Food, Beverages & Tobacco
# 190                                   AES                        Energy
# 31                                    IBM                    Technology
# 28                             Home Depot                     Retailing
# 310                               Autoliv        Motor Vehicles & Parts
# ...

# %% [markdown]
# ## Quick Object Conversions

# %%
data_from_web = pd.read_csv("https://data.kingcounty.gov/api/views/yaai-7frk/rows.csv?accessType=DOWNLOAD")
data_from_web.head(3)
# Out:
#    impound_no Animal_ID                              Data_Source Record_Type  \
# 0  K20-127100   A612714  Regional Animal Services of King County        LOST
# 1  K20-127715   A614138  Regional Animal Services of King County       FOUND
# 2  K20-127724   A614194  Regional Animal Services of King County       FOUND
#
#                                                 Link  \
# 0  https://petharbor.com/PublicDetail.asp?searcht...
# 1    https://petharbor.com/pet.asp?uaid=KING.A614138
# 2  https://kingcounty.gov/depts/regional-animal-s...
#
#                                     Current_Location Animal_Name animal_type  \
# 0                                               LOST     Bubbles         Dog
# 1  King County Pet Adoption Center 21615 64TH AVE...         NaN         Cat
# 2                                                NaN         NaN    Dead Cat
#
#        Age  Animal_Gender  ...    City State      Zip  jurisdiction  \
# ...

# %% [markdown]
# ## Export `DataFrame` to CSV File with the `.to_csv()` Method

# %%
cols = data_from_web.columns
cols
# Out:
# Index(['impound_no', 'Animal_ID', 'Data_Source', 'Record_Type', 'Link',
#        'Current_Location', 'Animal_Name', 'animal_type', 'Age',
#        'Animal_Gender', 'Animal_Breed', 'Animal_Color', 'Date', 'Date_Type',
#        'Obfuscated_Address', 'City', 'State', 'Zip', 'jurisdiction',
#        'obfuscated_latitude', 'obfuscated_longitude', 'Image',
#        'image_alt_text', 'Memo', 'Temperament'],
#       dtype='object')

# %%
data_from_web.to_csv("Animal_data.csv", index = False, columns = cols, encoding = "utf-8")

# %% [markdown]
# ## Import Excel File

# %%
df = pd.read_excel("data/Data - Single Worksheet.xlsx")
df
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
data = pd.read_excel("data/Data - Multiple Worksheets.xlsx", sheet_name = None)

# %%
type(data)
# Out:
# collections.OrderedDict

# %%
data
# Out:
# OrderedDict([('Data 1',   First Name Last Name           City Gender
#               0    Brandon     James          Miami      M
#               1       Sean   Hawkins         Denver      M
#               2       Judy       Day    Los Angeles      F
#               3     Ashley      Ruiz  San Francisco      F
#               4  Stephanie     Gomez       Portland      F),
#              ('Data 2',   First Name Last Name           City Gender
#               0     Parker     Power        Raleigh      F
#               1    Preston  Prescott   Philadelphia      F
#               2    Ronaldo   Donaldo         Bangor      M
#               3      Megan   Stiller  San Francisco      M
#               4     Bustin    Jieber         Austin      F)])

# %% [markdown]
# ## Export Excel File

# %%
data_from_web = pd.read_csv("https://data.kingcounty.gov/api/views/yaai-7frk/rows.csv?accessType=DOWNLOAD")
data_from_web.head(3)
# Out:
#    impound_no Animal_ID                              Data_Source Record_Type  \
# 0  K20-127100   A612714  Regional Animal Services of King County        LOST
# 1  K20-127715   A614138  Regional Animal Services of King County       FOUND
# 2  K20-127724   A614194  Regional Animal Services of King County       FOUND
#
#                                                 Link  \
# 0  https://petharbor.com/PublicDetail.asp?searcht...
# 1    https://petharbor.com/pet.asp?uaid=KING.A614138
# 2  https://kingcounty.gov/depts/regional-animal-s...
#
#                                     Current_Location Animal_Name animal_type  \
# 0                                               LOST     Bubbles         Dog
# 1  King County Pet Adoption Center 21615 64TH AVE...         NaN         Cat
# 2                                                NaN         NaN    Dead Cat
#
#        Age  Animal_Gender  ...    City State      Zip  jurisdiction  \
# ...

# %%
excel_file = pd.ExcelWriter("Animals data.xlsx")

# %%
data_from_web.to_excel(excel_file, sheet_name = "Animals", index = False, columns = cols)

# %%
excel_file.save()

# %% [markdown]
# ## The `pd.concat()` Method, Part 1

# %%
week1 = pd.read_csv("data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("data/Restaurant - Customers.csv")
foods = pd.read_csv("data/Restaurant - Foods.csv")

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
len(pd.concat([week1, week2]))
# Out:
# 500

# %% [markdown]
# ## The `pd.concat()` Method, Part 2

# %%
sales = pd.concat([week1, week2], keys = ["A", "B"])

# %%
sales
# Out:
#        Customer ID  Food ID
# A 0            537        9
#   1             97        4
#   2            658        1
#   3            202        2
#   4            155        9
#   5            213        8
#   6            600        1
#   7            503        5
#   8             71        3
#   9            174        3
#   10           961        9
#   11           966        5
#   12           641        4
#   13           288        2
#   14           149        4
#   15           954        2
#   16           147        9
#   17           155        1
#   18           550        6
#   19           101        7
#   20           549        6
#   21            75        6
#   22            78        7
#   23           514        5
#   24           833        7
#   25           329        8
#   26           586       10
#   27           341        1
#   28           519       10
#   29           680        9
# ...            ...      ...
# B 220          495        2
# ...

# %%
sales.loc[("B", 240), "Customer ID"]
# Out:
# 734

# %% [markdown]
# ## The `.append()` Method

# %%
sales = week2.append(week1, ignore_index = True)

# %%
print(week1.shape[0])
print(week2.shape[0])
# Out:
# 250
# 250

# %%
sales.shape[0]
# Out:
# 500

# %% [markdown]
# ## Inner Joins, Part 1

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.merge(week2, how = "inner", on = "Customer ID", suffixes = [" - A", " - B"])
# Out:
#     Customer ID  Food ID - A  Food ID - B
# 0           537            9            5
# 1           155            9            3
# 2           155            1            3
# 3           503            5            8
# 4           503            5            9
# 5           550            6            7
# 6           101            7            4
# 7            75            6            4
# 8            77            1            7
# 9            77            9            7
# 10           77            2            7
# 11           77            9            7
# 12          628            4            7
# 13          798            9            5
# 14          798            1            5
# 15          462            3            8
# 16          304            3            3
# 17          304            2            3
# 18          189            4            5
# 19          799            8            7
# 20           30            2            4
# ...

# %%
week1[week1["Customer ID"] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %% [markdown]
# ## Inner Joins, Part 2

# %%
week1 = pd.read_csv("data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("data/Restaurant - Customers.csv")
foods = pd.read_csv("data/Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.merge(week2, how = "inner", on = ["Customer ID", "Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1[week1["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 224          578        5

# %%
week2[week2["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 29           578        5
# 189          578        5

# %% [markdown]
# ## Outer Joins

# %%
week1 = pd.read_csv("data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("data/Restaurant - Customers.csv")
foods = pd.read_csv("data/Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
merged = week1.merge(week2, how = "outer", on = "Customer ID", suffixes = [" - Week 1", " - Week 2"],
            indicator = True)

# %%
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
mask = merged["_merge"].isin(["left_only", "right_only"])
merged[mask]
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week 2      _merge
# 1             97               4.0               NaN   left_only
# 2            658               1.0               NaN   left_only
# 3            202               2.0               NaN   left_only
# 6            213               8.0               NaN   left_only
# 7            600               1.0               NaN   left_only
# 10            71               3.0               NaN   left_only
# 11            71               8.0               NaN   left_only
# 12           174               3.0               NaN   left_only
# 13           961               9.0               NaN   left_only
# 14           966               5.0               NaN   left_only
# 15           641               4.0               NaN   left_only
# 16           288               2.0               NaN   left_only
# 17           149               4.0               NaN   left_only
# ...

# %% [markdown]
# ## Left Joins

# %%
week1 = pd.read_csv("data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("data/Restaurant - Customers.csv")
foods = pd.read_csv("data/Restaurant - Foods.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
week1 = week1.merge(foods, how = "left", on = "Food ID", sort = True)

# %%
week1.head()
# Out:
#    Customer ID  Food ID Food Item  Price
# 0          658        1     Sushi   3.99
# 1          600        1     Sushi   3.99
# 2          155        1     Sushi   3.99
# 3          341        1     Sushi   3.99
# 4           20        1     Sushi   3.99

# %% [markdown]
# ## The `left_on` and `right_on` Parameters

# %%
week1 = pd.read_csv("data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("data/Restaurant - Customers.csv")
foods = pd.read_csv("data/Restaurant - Foods.csv")

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
week2 = week2.merge(customers, how = "left", left_on = "Customer ID", right_on = "ID", sort = True).drop("ID", axis = "columns")

# %%
week2.head()
# Out:
#    Customer ID  Food ID First Name Last Name  Gender        Company  \
# 0            8        6    Frances     Adams  Female       Dabshots
# 1           13        2       Ruth   Alvarez  Female    Twitterlist
# 2           21        4     Albert     Burns    Male      Rhynoodle
# 3           24        8      Donna    Thomas  Female        Jaxbean
# 4           27        4    Jessica   Bennett  Female  Twitternation
#
#                     Occupation
# 0                Developer III
# 1  Mechanical Systems Engineer
# 2             Junior Executive
# 3        Chief Design Engineer
# 4            Account Executive

# %% [markdown]
# ## Merging by Indexes with the `left_index` and `right_index` Parameters

# %%
week1 = pd.read_csv("data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("data/Restaurant - Customers.csv")
foods = pd.read_csv("data/Restaurant - Foods.csv")

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
sales = week1.merge(customers, how = "left", left_on = "Customer ID", right_index = True)
sales = sales.merge(foods, how = "left", left_on = "Food ID", right_index = True)
sales.head(3)
# Out:
#    Customer ID  Food ID_x     ID First Name   Last Name  Gender     Company  \
# 0          537          9  538.0       Sara  Washington  Female      Skimia
# 1           97          4   98.0       Jean       Mills  Female  Fivebridge
# 2          658          1  659.0     Howard      Hudson    Male  Topicshots
#
#                    Occupation  Food ID_y Food Item  Price
# 0  Database Administrator III       10.0     Drink   1.75
# 1            Product Engineer        5.0     Pizza   2.49
# 2                   Professor        2.0   Burrito   9.99

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
week1.merge(week2, how = "left", left_index = True, right_index = True, suffixes = [" - Week 1", " - Week 2"])
# Out:
#      Customer ID - Week 1  Food ID - Week 1  Customer ID - Week 2  \
# 0                     537                 9                   688
# 1                      97                 4                   813
# 2                     658                 1                   495
# 3                     202                 2                   189
# 4                     155                 9                   267
# 5                     213                 8                   310
# 6                     600                 1                   761
# 7                     503                 5                   443
# 8                      71                 3                   729
# 9                     174                 3                   741
# 10                    961                 9                   847
# 11                    966                 5                   156
# 12                    641                 4                   550
# ...

# %% [markdown]
# ## The `.join()` Method

# %%
week1 = pd.read_csv("data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("data/Restaurant - Customers.csv")
foods = pd.read_csv("data/Restaurant - Foods.csv")
satisfaction = pd.read_csv("data/Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
satisfaction.head(3)
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3

# %%
week1.merge(satisfaction, how = "left", left_index = True, right_index = True).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %%
week1.join(satisfaction).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %% [markdown]
# ## The `pd.merge()` Method

# %%
week1 = pd.read_csv("data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("data/Restaurant - Customers.csv")
foods = pd.read_csv("data/Restaurant - Foods.csv")
satisfaction = pd.read_csv("data/Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
pd.merge(week1, customers, how = "left", left_on = "Customer ID", right_on = "ID")
# Out:
#      Customer ID  Food ID   ID First Name  Last Name  Gender       Company  \
# 0            537        9  537     Cheryl    Carroll  Female      Zoombeat
# 1             97        4   97     Amanda    Watkins  Female           Ozu
# 2            658        1  658    Patrick       Webb    Male     Browsebug
# 3            202        2  202      Louis   Campbell    Male     Rhynoodle
# 4            155        9  155    Carolyn       Diaz  Female      Gigazoom
# 5            213        8  213      Keith     Foster    Male     Gigashots
# 6            600        1  600     Sandra     Bailey  Female     Jaxnation
# 7            503        5  503     Justin    Daniels    Male          Oloo
# 8             71        3   71    Carolyn      Reyes  Female        Twimbo
# 9            174        3  174       Anna     Miller  Female       Innojam
# 10           961        9  961      Ralph   Richards    Male  Thoughtstorm
# ...
