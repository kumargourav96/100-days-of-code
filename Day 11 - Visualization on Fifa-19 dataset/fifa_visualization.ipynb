# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the dataset
fifa = pd.read_csv('data.csv')

# %%
# [The link for the dataset]('https://www.kaggle.com/karangadiya/fifa19')

# %%
# Printing few rows of the dataset
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# Print info of the dataset
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
# Describe data
fifa.describe().T
# Out:
#                  count           mean           std   min       25%       50%  \
# Unnamed: 0     18207.0    9103.000000   5256.052511   0.0    4551.5    9103.0
# ID             18207.0  214298.338606  29965.244204  16.0  200315.5  221759.0
# Age            18207.0      25.122206      4.669943  16.0      21.0      25.0
# Overall        18207.0      66.238699      6.908930  46.0      62.0      66.0
# Potential      18207.0      71.307299      6.136496  48.0      67.0      71.0
# ...                ...            ...           ...   ...       ...       ...
# GKDiving       18159.0      16.616223     17.695349   1.0       8.0      11.0
# GKHandling     18159.0      16.391596     16.906900   1.0       8.0      11.0
# GKKicking      18159.0      16.232061     16.502864   1.0       8.0      11.0
# GKPositioning  18159.0      16.388898     17.034669   1.0       8.0      11.0
# GKReflexes     18159.0      16.710887     17.955119   1.0       8.0      11.0
#
# ...

# %% [markdown]
# ### Check for null values

# %%
fifa.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
fifa.drop('Unnamed: 0', axis = 1, inplace = True)

# %% [markdown]
# ### Total number of Nations participating in FIFA

# %%
fifa['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
print('Total number of countries participating in FIFA are: ',fifa['Nationality'].nunique())
# Out:
# Total number of countries participating in FIFA are:  164

# %% [markdown]
# ### Which and howmany different teams are participating

# %%
Club = fifa.Club.unique()
Club
# Out:
# array(['FC Barcelona', 'Juventus', 'Paris Saint-Germain',
#        'Manchester United', 'Manchester City', 'Chelsea', 'Real Madrid',
#        'Atlético Madrid', 'FC Bayern München', 'Tottenham Hotspur',
#        'Liverpool', 'Napoli', 'Arsenal', 'Milan', 'Inter', 'Lazio',
#        'Borussia Dortmund', 'Vissel Kobe', 'Olympique Lyonnais', 'Roma',
#        'Valencia CF', 'Guangzhou Evergrande Taobao FC', 'FC Porto',
#        'FC Schalke 04', 'Beşiktaş JK', 'LA Galaxy', 'Sporting CP',
#        'Real Betis', 'Olympique de Marseille', 'RC Celta',
#        'Bayer 04 Leverkusen', 'Real Sociedad', 'Villarreal CF',
#        'Sevilla FC', 'SL Benfica', 'AS Saint-Étienne', 'AS Monaco',
#        'Leicester City', 'Atalanta', 'Grêmio', 'Atlético Mineiro',
#        'RB Leipzig', 'Ajax', 'Dalian YiFang FC', 'Everton',
#        'West Ham United', '1. FC Köln', 'TSG 1899 Hoffenheim',
#        'Shanghai SIPG FC', 'OGC Nice', 'Al Nassr',
#        'Wolverhampton Wanderers', 'Borussia Mönchengladbach',
# ...

# %%
print('Total number of Clubs participating are: ',len(Club))
# Out:
# Total number of Clubs participating are:  652

# %% [markdown]
# ### Data Cleansing

# %% [markdown]
# ### Checking for missing values

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
fifa.isna().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Special                         0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Real Face                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# ...

# %%
pd.set_option('display.max_rows', 10)

# %%
original = fifa.copy()

# %%
fifa['ShortPassing'].fillna(fifa['ShortPassing'].mean(), inplace = True)
fifa['Volleys'].fillna(fifa['Volleys'].mean(), inplace = True)
fifa['Dribbling'].fillna(fifa['Dribbling'].mean(), inplace = True)
fifa['Curve'].fillna(fifa['Curve'].mean(), inplace = True)
fifa['FKAccuracy'].fillna(fifa['FKAccuracy'].mean(), inplace = True)
fifa['LongPassing'].fillna(fifa['LongPassing'].mean(), inplace = True)
fifa['BallControl'].fillna(fifa['BallControl'].mean(), inplace = True)
fifa['HeadingAccuracy'].fillna(fifa['HeadingAccuracy'].mean(), inplace = True)
fifa['Finishing'].fillna(fifa['Finishing'].mean(), inplace = True)
fifa['Crossing'].fillna(fifa['Crossing'].mean(), inplace = True)
fifa['Weight'].fillna(fifa['Weight'].mode(), inplace = True)
fifa['Contract Valid Until'].fillna(2019, inplace = True)
fifa['Height'].fillna(fifa['Height'].mode(), inplace = True)
fifa['Loaned From'].fillna('None', inplace = True)
fifa['Joined'].fillna('Jul 1, 2018', inplace = True)
fifa['Jersey Number'].fillna(8, inplace = True)
fifa['Body Type'].fillna('Normal', inplace = True)
fifa['Position'].fillna('ST', inplace = True)
fifa['Club'].fillna('No Club', inplace = True)
fifa['Work Rate'].fillna('Medium', inplace = True)
fifa['Skill Moves'].fillna(fifa['Skill Moves'].median(), inplace = True)
fifa['Weak Foot'].fillna(3, inplace = True)
fifa['Preferred Foot'].fillna('Right', inplace = True)
fifa['International Reputation'].fillna(1, inplace = True)
fifa['Wage'].fillna('€200K', inplace = True)

# %% [markdown]
# ### Filter players on basis of country

# %%
def country(x):
    return fifa[fifa['Nationality'].str.lower()==x][['Name','Jersey Number','Position','Overall','Nationality','Age','Wage',
                                    'Value','Contract Valid Until']]

# %%
country('india')
# Out:
#                   Name  Jersey Number Position  Overall Nationality  Age Wage  \
# 8605        S. Chhetri           11.0       LS       67       India   33   €0
# 10011       S. Jhingan            5.0      RCB       65       India   24   €0
# 12598    J. Lalpekhlua           12.0       RS       63       India   27   €0
# 12811  G. Singh Sandhu           23.0       GK       63       India   26   €0
# 13508    A. Edathodika           22.0      LCB       62       India   31   €0
# ...                ...            ...      ...      ...         ...  ...  ...
# 17129         J. Singh            8.0       ST       55       India   26   €0
# 17197         V. Kaith            1.0       GK       55       India   21   €0
# 17339         S. Passi            8.0       ST       54       India   23   €0
# 17436   D. Lalhlimpuia            8.0       ST       54       India   20   €0
# 17539         C. Singh            8.0       ST       53       India   21   €0
#
#       Value Contract Valid Until
# ...

# %%
country('spain')
# Out:
#                       Name  Jersey Number Position  Overall Nationality  Age  \
# 3                   De Gea            1.0       GK       91       Spain   27
# 8             Sergio Ramos           15.0      RCB       91       Spain   32
# 13             David Silva           21.0      LCM       90       Spain   32
# 20         Sergio Busquets            5.0      CDM       89       Spain   29
# 30                    Isco           22.0       LW       88       Spain   26
# ...                    ...            ...      ...      ...         ...  ...
# 17043        Cristian Arco           26.0       GK       55       Spain   23
# 17070               Taliby           35.0       GK       55       Spain   21
# 17116         Víctor Gómez           33.0       LB       55       Spain   18
# 17274            Hugo Díaz           44.0       CB       55       Spain   21
# 17926  Carlos Mendes Gomes           19.0      CAM       51       Spain   19
#
#         Wage   Value Contract Valid Until
# ...

# %% [markdown]
# ### Filter player on basis of Club

# %%
def club_filter(x):
    return fifa[fifa['Club'].str.lower()==x][['Name','Jersey Number','Position','Overall','Nationality','Age','Wage',
                                    'Value','Contract Valid Until']]

# %%
club_filter('manchester united')
# Out:
#               Name  Jersey Number Position  Overall Nationality  Age   Wage  \
# 3           De Gea            1.0       GK       91       Spain   27  €260K
# 45        P. Pogba            6.0      RDM       87      France   25  €210K
# 47       R. Lukaku            9.0       ST       87     Belgium   25  €230K
# 93      A. Sánchez            7.0       RW       85       Chile   29  €215K
# 116     A. Martial           11.0       LW       84      France   22  €165K
# ...            ...            ...      ...      ...         ...  ...    ...
# 10457  E. Hamilton           48.0       CM       65    Scotland   19   €11K
# 10461   C. Gribbin           42.0      CAM       65     England   19   €11K
# 11081     R. Poole           50.0       CB       64       Wales   20   €13K
# 11422  R. Williams           52.0       CB       64     England   19    €8K
# 12545     J. Bohui           46.0       ST       63     England   19   €10K
#
#         Value Contract Valid Until
# ...

# %%
club_filter('chelsea')
# Out:
#                       Name  Jersey Number Position  Overall Nationality  Age  \
# 5                E. Hazard           10.0       LF       91     Belgium   27
# 14                N. Kanté           13.0      LDM       89      France   27
# 69             Azpilicueta           14.0       RB       86       Spain   28
# 121               Jorginho            8.0       CM       84       Italy   26
# 140                Willian           22.0       RW       84      Brazil   29
# ...                    ...            ...      ...      ...         ...  ...
# 14603           B. Gilmour           60.0       CM       61    Scotland   17
# 14646  M. Taylor-Crossdale           56.0       ST       61     England   18
# 15322         G. McEachran           55.0      CAM       59     England   17
# 15846             M. Guehi           53.0       CB       58     England   17
# 16806             M. Bulka           59.0       GK       56      Poland   18
#
#         Wage   Value Contract Valid Until
# ...

# %%
club_filter('real madrid')
# Out:
#                 Name  Jersey Number Position  Overall Nationality  Age   Wage  \
# 6          L. Modrić           10.0      RCM       91     Croatia   32  €420K
# 8       Sergio Ramos           15.0      RCB       91       Spain   32  €380K
# 11          T. Kroos            8.0      LCM       90     Germany   28  €355K
# 19       T. Courtois            1.0       GK       89     Belgium   26  €240K
# 27          Casemiro           14.0      CDM       88      Brazil   26  €285K
# ...              ...            ...      ...      ...         ...  ...    ...
# 11163   Sergio López           32.0       RB       64       Spain   19    €9K
# 11327    Fran García           37.0       LB       64       Spain   18    €9K
# 11877  Manu Hernando           33.0       CB       64       Spain   19    €9K
# 12504     Dani Gómez           38.0       ST       63       Spain   19   €12K
# 13687      L. Zidane           30.0       GK       62      France   20    €9K
#
# ...

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# ### Most popular foot

# %%
sns.countplot(fifa['Preferred Foot'])
plt.title('Most Preferred Foot of the Players', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Most Preferred Foot of the Players')

# %%
plt.figure(figsize = (20,7))
plt.style.use('fivethirtyeight')
sns.countplot(fifa['Position'])
plt.title('Comparision of Players and Positions', fontsize = 15)
plt.xlabel('Positions')
plt.ylabel('No. of Players')
# Out:
# Text(0, 0.5, 'No. of Players')

# %% [markdown]
# ### Distribution of Age of Players

# %%
sns.distplot(fifa['Age'])
plt.title('Distribution of Age of Players', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Distribution of Age of Players')

# %% [markdown]
# ### Distribution of wages of Players

# %%
def extract_value_from(Value):
    out = Value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', ''))*1000000
    elif 'K' in Value:
        out = float(out.replace('K', ''))*1000
    return float(out)

# applying the function to the wage column
# fifa['Value'] = fifa['Value'].apply(lambda x: extract_value_from(x))
fifa['Wage'] = fifa['Wage'].apply(lambda x: extract_value_from(x))
fifa['Wage'].head()
# Out:
# 0    565000.0
# 1    405000.0
# 2    290000.0
# 3    260000.0
# 4    355000.0
# Name: Wage, dtype: float64

# %%
plt.figure(figsize = (15,7))
plt.hist(fifa['Wage'], bins = 1000)
plt.title('Distribution of Wages of Players', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Distribution of Wages of Players')

# %% [markdown]
# ### Top 10 wages in the World

# %%
top_ten = fifa.sort_values(by = 'Wage', ascending = False).head(10)

# %%
plt.figure(figsize = (15,5))
sns.lineplot('Name', 'Wage', data = top_ten)
plt.title('Top ten Wages of Players', fontsize = 15)
plt.xlabel('Players Name',fontsize = 15)
plt.ylabel('Wage', fontsize = 15)
# Out:
# Text(0, 0.5, 'Wage')

# %% [markdown]
# ### Top 10 Fastest Player in the world

# %%
top_speed = fifa.sort_values(by=['SprintSpeed'], ascending=False).head(10)

# %%
plt.figure(figsize = (15,5))
plt.plot(top_speed['Name'], top_speed['SprintSpeed'])
plt.title('Top 10 Players with Higest Sprint Speed', fontsize = 15)
plt.xlabel('Players Name',fontsize = 15)
plt.ylabel('Sprint Speed', fontsize = 15)
# Out:
# Text(0, 0.5, 'Sprint Speed')

# %% [markdown]
# ### Most Internationally reputed player in the world

# %%
reputation = fifa.sort_values(by = 'International Reputation', ascending = False).head(10)

# %%
reputation[['International Reputation','Name']]
# Out:
#      International Reputation               Name
# 0                         5.0           L. Messi
# 2                         5.0          Neymar Jr
# 22                        5.0           M. Neuer
# 109                       5.0     Z. Ibrahimović
# 7                         5.0          L. Suárez
# 1                         5.0  Cristiano Ronaldo
# 93                        4.0         A. Sánchez
# 54                        4.0              Piqué
# 53                        4.0         I. Rakitić
# 552                       4.0          W. Rooney

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,7))
sns.barplot(reputation['Name'], reputation['International Reputation'])
plt.title('Top 10 Internationally Reputed Players', fontsize = 15)
plt.xlabel('Players Name',fontsize = 15)
plt.ylabel('Rating', fontsize = 15)
# plt.ylim(0,5)
# Out:
# Text(0, 0.5, 'Rating')

# %% [markdown]
# ### Position and Jersy Number of top Players

# %%
reputation[['Name','Position','Jersey Number']]
# Out:
#                   Name Position  Jersey Number
# 0             L. Messi       RF           10.0
# 2            Neymar Jr       LW           10.0
# 22            M. Neuer       GK            1.0
# 109     Z. Ibrahimović       RS            9.0
# 7            L. Suárez       RS            9.0
# 1    Cristiano Ronaldo       ST            7.0
# 93          A. Sánchez       RW            7.0
# 54               Piqué      RCB            3.0
# 53          I. Rakitić      RCM            4.0
# 552          W. Rooney       ST            9.0

# %% [markdown]
# ### Count of players on basis of their height

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,7))
sns.countplot(fifa['Height'])
plt.title('Count of Players on basis of their Height', fontsize = 15)
plt.xlabel('Players Name',fontsize = 15)
plt.ylabel('Count of Players', fontsize = 15)
# plt.ylim(0,5)
# Out:
# Text(0, 0.5, 'Count of Players')

# %% [markdown]
# ### Count of Players on basis of their Weight

# %%
def extract_weight(x):
    weight = x.replace('lbs','')
    return float(weight)
fifa['Weight'] = fifa['Weight'].apply(lambda x: extract_weight(str(x)))

# %%
fifa['Weight'].fillna(fifa['Weight'].mean(), inplace = True)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,7))
sns.distplot(fifa['Weight'])
plt.title('Different Weight of the Players', fontsize = 15)
plt.xlabel('Weight associated with the Players',fontsize = 15)
plt.ylabel('Count of Players', fontsize = 15)
# plt.ylim(0,5)
# Out:
# Text(0, 0.5, 'Count of Players')

# %% [markdown]
# ### Count of Work Rate

# %%
plt.figure(figsize = (15,5))
sns.countplot(fifa['Work Rate'])
plt.title('Count of Work Rate')
plt.ylabel('Count of Players')
# Out:
# Text(0, 0.5, 'Count of Players')

# %% [markdown]
# ### Count of Players on basis of their Stamina

# %%
fifa.Stamina.fillna(fifa['Stamina'].mean(), inplace = True)

# %%
sns.set(style="whitegrid")
plt.figure(figsize = (15,7))
sns.distplot(fifa.Stamina)
plt.title('Count of Players on basis of Stamina', fontsize = 15)
plt.xlabel('Stamina associated with the Players',fontsize = 15)
plt.ylabel('Count of Players', fontsize = 15)
# plt.ylim(0,5)
# Out:
# Text(0, 0.5, 'Count of Players')

# %% [markdown]
# ### Body type of top most famous Players

# %%
reputation[['Name', 'Body Type']]
# Out:
#                   Name   Body Type
# 0             L. Messi       Messi
# 2            Neymar Jr      Neymar
# 22            M. Neuer      Normal
# 109     Z. Ibrahimović      Normal
# 7            L. Suárez      Normal
# 1    Cristiano Ronaldo  C. Ronaldo
# 93          A. Sánchez      Normal
# 54               Piqué      Normal
# 53          I. Rakitić      Normal
# 552          W. Rooney      Stocky

# %%
plt.figure(figsize = (15,5))
plt.plot(reputation['Name'], reputation['Body Type'])

# %% [markdown]
# ### Relation between Players age and work rate

# %%
plt.figure(figsize = (15,7))
sns.barplot('Work Rate', 'Age', data = fifa)
plt.title('Relation between Work Rate and Age', fontsize = 15)
plt.xlabel('Work Rate')
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')
