# %%
import pandas as pd

# %%
nba = pd.read_csv("data/nba.csv")

# %% [markdown]
# ## Shared Methods and Attributes

# %%
nba = pd.read_csv("data/nba.csv")

# %%
nba.head(1)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#   College     Salary
# 0   Texas  7730337.0

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %%
rev = pd.read_csv("data/revenue.csv", index_col = "Date")
rev.head(3)
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933

# %%
s = pd.Series([1, 2, 3])
s.sum()
# Out:
# 6

# %%
rev.sum(axis = "columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %% [markdown]
# ## Select One Column from a `DataFrame`

# %%
nba = pd.read_csv("data/nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %% [markdown]
# ## Select Two or More Columns from A `DataFrame`

# %%
nba = pd.read_csv("data/nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba[["Team", "Name"]].head(3)
nba[["Number", "College"]]
nba[["Salary", "Team", "Name"]].tail()
# Out:
#         Salary       Team          Name
# 453  2433333.0  Utah Jazz  Shelvin Mack
# 454   900000.0  Utah Jazz     Raul Neto
# 455  2900000.0  Utah Jazz  Tibor Pleiss
# 456   947276.0  Utah Jazz   Jeff Withey
# 457        NaN        NaN           NaN

# %%
select = ["Salary", "Team", "Name"]
nba[select]
# Out:
#          Salary                    Team                     Name
# 0     7730337.0          Boston Celtics            Avery Bradley
# 1     6796117.0          Boston Celtics              Jae Crowder
# 2           NaN          Boston Celtics             John Holland
# 3     1148640.0          Boston Celtics              R.J. Hunter
# 4     5000000.0          Boston Celtics            Jonas Jerebko
# 5    12000000.0          Boston Celtics             Amir Johnson
# 6     1170960.0          Boston Celtics            Jordan Mickey
# 7     2165160.0          Boston Celtics             Kelly Olynyk
# 8     1824360.0          Boston Celtics             Terry Rozier
# 9     3431040.0          Boston Celtics             Marcus Smart
# 10    2569260.0          Boston Celtics          Jared Sullinger
# 11    6912869.0          Boston Celtics            Isaiah Thomas
# 12    3425510.0          Boston Celtics              Evan Turner
# 13    1749840.0          Boston Celtics              James Young
# 14    2616975.0          Boston Celtics             Tyler Zeller
# 15    3425510.0           Brooklyn Nets         Bojan Bogdanovic
# 16     845059.0           Brooklyn Nets             Markel Brown
# 17    1500000.0           Brooklyn Nets          Wayne Ellington
# 18    1335480.0           Brooklyn Nets  Rondae Hollis-Jefferson
# 19    6300000.0           Brooklyn Nets             Jarrett Jack
# 20    1599840.0           Brooklyn Nets           Sergey Karasev
# 21     134215.0           Brooklyn Nets          Sean Kilpatrick
# 22    1500000.0           Brooklyn Nets             Shane Larkin
# 23   19689000.0           Brooklyn Nets              Brook Lopez
# 24    1140240.0           Brooklyn Nets         Chris McCullough
# 25     947276.0           Brooklyn Nets              Willie Reed
# 26     981348.0           Brooklyn Nets          Thomas Robinson
# 27     947276.0           Brooklyn Nets               Henry Sims
# 28     947276.0           Brooklyn Nets             Donald Sloan
# 29   11235955.0           Brooklyn Nets           Thaddeus Young
# ..          ...                     ...                      ...
# 428   8042895.0  Portland Trail Blazers          Al-Farouq Aminu
# 429    625093.0  Portland Trail Blazers          Pat Connaughton
# 430    947276.0  Portland Trail Blazers             Allen Crabbe
# 431   6980802.0  Portland Trail Blazers                 Ed Davis
# 432   2894059.0  Portland Trail Blazers         Maurice Harkless
# 433   6000000.0  Portland Trail Blazers         Gerald Henderson
# 434   5016000.0  Portland Trail Blazers              Chris Kaman
# 435   3075880.0  Portland Trail Blazers           Meyers Leonard
# 436   4236287.0  Portland Trail Blazers           Damian Lillard
# 437   2525160.0  Portland Trail Blazers            C.J. McCollum
# 438    525093.0  Portland Trail Blazers             Luis Montero
# 439   1415520.0  Portland Trail Blazers            Mason Plumlee
# 440   2854940.0  Portland Trail Blazers            Brian Roberts
# 441   2637720.0  Portland Trail Blazers              Noah Vonleh
# 442   4775000.0               Utah Jazz            Trevor Booker
# 443   2658240.0               Utah Jazz               Trey Burke
# 444   9463484.0               Utah Jazz               Alec Burks
# 445   3777720.0               Utah Jazz               Dante Exum
# 446  12000000.0               Utah Jazz           Derrick Favors
# 447   1175880.0               Utah Jazz              Rudy Gobert
# 448  15409570.0               Utah Jazz           Gordon Hayward
# 449   1348440.0               Utah Jazz              Rodney Hood
# 450   2050000.0               Utah Jazz               Joe Ingles
# 451    981348.0               Utah Jazz            Chris Johnson
# 452   2239800.0               Utah Jazz               Trey Lyles
# 453   2433333.0               Utah Jazz             Shelvin Mack
# 454    900000.0               Utah Jazz                Raul Neto
# 455   2900000.0               Utah Jazz             Tibor Pleiss
# 456    947276.0               Utah Jazz              Jeff Withey
# 457         NaN                     NaN                      NaN
#
# [458 rows x 3 columns]

# %% [markdown]
# ## Add New Column to `DataFrame`

# %%
nba["Sport"] = "Basketball"
nba.head(3)

nba["League"] = "National Basketball Association"
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary       Sport                           League
# 0              Texas  7730337.0  Basketball  National Basketball Association
# 1          Marquette  6796117.0  Basketball  National Basketball Association
# 2  Boston University        NaN  Basketball  National Basketball Association

# %%
nba = pd.read_csv("data/nba.csv")

nba.insert(3, column = "Sport", value = "Basketball")
nba.head(3)

nba.insert(7, column = "League", value = "National Basketball Association")
nba.head()
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#                             League  Weight            College     Salary
# 0  National Basketball Association   180.0              Texas  7730337.0
# 1  National Basketball Association   235.0          Marquette  6796117.0
# 2  National Basketball Association   205.0  Boston University        NaN
# 3  National Basketball Association   185.0      Georgia State  1148640.0
# 4  National Basketball Association   231.0                NaN  5000000.0

# %% [markdown]
# ## Broadcasting Operations

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#                             League  Weight            College     Salary
# 0  National Basketball Association   180.0              Texas  7730337.0
# 1  National Basketball Association   235.0          Marquette  6796117.0
# 2  National Basketball Association   205.0  Boston University        NaN

# %%
nba["Age"].add(5)
nba["Age"] + 5

nba["Salary"].sub(5000000)
nba["Salary"] - 5000000

nba["Weight"].mul(0.453592)
nba["Weight in Kilograms"] = nba["Weight"] * 0.453592

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#                             League  Weight            College     Salary  \
# 0  National Basketball Association   180.0              Texas  7730337.0
# 1  National Basketball Association   235.0          Marquette  6796117.0
# 2  National Basketball Association   205.0  Boston University        NaN
#
#    Weight in Kilograms
# 0             81.64656
# 1            106.59412
# 2             92.98636

# %%
nba["Salary"].div(1000000)
nba["Salary in Millions"] = nba["Salary"] / 1000000

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#                             League  Weight            College     Salary  \
# 0  National Basketball Association   180.0              Texas  7730337.0
# 1  National Basketball Association   235.0          Marquette  6796117.0
# 2  National Basketball Association   205.0  Boston University        NaN
#
#    Weight in Kilograms  Salary in Millions
# 0             81.64656            7.730337
# 1            106.59412            6.796117
# 2             92.98636                 NaN

# %% [markdown]
# ## A Review of the `.value_counts()` Method

# %%
nba = pd.read_csv("data/nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Team"].value_counts()
nba["Position"].value_counts().head(1)
nba["Weight"].value_counts().tail()
nba["Salary"].value_counts()
# Out:
# 947276.0      31
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 1100602.0      5
# 16407500.0     5
# 5000000.0      5
# 12000000.0     5
# 8000000.0      5
# 4000000.0      5
# 3000000.0      4
# 7000000.0      4
# 2814000.0      4
# 1000000.0      4
# 19689000.0     4
# 200600.0       3
# 8500000.0      3
# 2500000.0      3
# 1015421.0      3
# 2854940.0      3
# 13500000.0     3
# 5543725.0      3
# 2288205.0      2
# 1270964.0      2
# 2900000.0      2
# 1007026.0      2
# 111444.0       2
# 13000000.0     2
# 1500000.0      2
# 1842000.0      2
#               ..
# 2239800.0      1
# 1474440.0      1
# 19688000.0     1
# 7900000.0      1
# 2008748.0      1
# 13800000.0     1
# 2841960.0      1
# 1404600.0      1
# 1584480.0      1
# 273038.0       1
# 9213483.0      1
# 3272091.0      1
# 3075880.0      1
# 2250000.0      1
# 4626960.0      1
# 1304520.0      1
# 12100000.0     1
# 7500000.0      1
# 295327.0       1
# 2836186.0      1
# 6486486.0      1
# 5016000.0      1
# 3333333.0      1
# 1824360.0      1
# 8042895.0      1
# 1242720.0      1
# 2489530.0      1
# 5103120.0      1
# 9463484.0      1
# 700902.0       1
# Name: Salary, Length: 309, dtype: int64

# %% [markdown]
# ## Drop Rows with Null Values

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.dropna(how = "all", inplace = True)

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
#
#         Salary
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.dropna(subset = ["Salary", "College"])
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 26           Thomas Robinson           Brooklyn Nets    41.0       PF  25.0
# 27                Henry Sims           Brooklyn Nets    14.0        C  26.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 29            Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# 441    6-9   240.0           Indiana   2637720.0
# 442    6-8   228.0           Clemson   4775000.0
# 443    6-1   191.0          Michigan   2658240.0
# 444    6-6   214.0          Colorado   9463484.0
# 446   6-10   265.0      Georgia Tech  12000000.0
# 448    6-8   226.0            Butler  15409570.0
# 449    6-8   206.0              Duke   1348440.0
# 451    6-6   206.0            Dayton    981348.0
# 452   6-10   234.0          Kentucky   2239800.0
# 453    6-3   203.0            Butler   2433333.0
# 456    7-0   231.0            Kansas    947276.0
#
# [364 rows x 9 columns]

# %% [markdown]
# ## Fill in Null Values with the `.fillna()` Method

# %%
nba = pd.read_csv("data/nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.fillna(0)
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# 13               James Young          Boston Celtics    13.0       SG  20.0
# 14              Tyler Zeller          Boston Celtics    44.0        C  26.0
# 15          Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0
# 16              Markel Brown           Brooklyn Nets    22.0       SG  24.0
# 17           Wayne Ellington           Brooklyn Nets    21.0       SG  28.0
# 18   Rondae Hollis-Jefferson           Brooklyn Nets    24.0       SG  21.0
# 19              Jarrett Jack           Brooklyn Nets     2.0       PG  32.0
# 20            Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 21           Sean Kilpatrick           Brooklyn Nets     6.0       SG  26.0
# 22              Shane Larkin           Brooklyn Nets     0.0       PG  23.0
# 23               Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 24          Chris McCullough           Brooklyn Nets     1.0       PF  21.0
# 25               Willie Reed           Brooklyn Nets    33.0       PF  26.0
# 26           Thomas Robinson           Brooklyn Nets    41.0       PF  25.0
# 27                Henry Sims           Brooklyn Nets    14.0        C  26.0
# 28              Donald Sloan           Brooklyn Nets    15.0       PG  28.0
# 29            Thaddeus Young           Brooklyn Nets    30.0       PF  27.0
# ..                       ...                     ...     ...      ...   ...
# 428          Al-Farouq Aminu  Portland Trail Blazers     8.0       SF  25.0
# 429          Pat Connaughton  Portland Trail Blazers     5.0       SG  23.0
# 430             Allen Crabbe  Portland Trail Blazers    23.0       SG  24.0
# 431                 Ed Davis  Portland Trail Blazers    17.0        C  27.0
# 432         Maurice Harkless  Portland Trail Blazers     4.0       SF  23.0
# 433         Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0
# 430    6-6   210.0         California    947276.0
# 431   6-10   240.0     North Carolina   6980802.0
# 432    6-9   215.0         St. John's   2894059.0
# 433    6-5   215.0               Duke   6000000.0
# 434    7-0   265.0   Central Michigan   5016000.0
# 435    7-1   245.0           Illinois   3075880.0
# 436    6-3   195.0        Weber State   4236287.0
# 437    6-4   200.0             Lehigh   2525160.0
# 438    6-7   185.0     Westchester CC    525093.0
# 439   6-11   235.0               Duke   1415520.0
# 440    6-1   173.0             Dayton   2854940.0
# 441    6-9   240.0            Indiana   2637720.0
# 442    6-8   228.0            Clemson   4775000.0
# 443    6-1   191.0           Michigan   2658240.0
# 444    6-6   214.0           Colorado   9463484.0
# 445    6-6   190.0                  0   3777720.0
# 446   6-10   265.0       Georgia Tech  12000000.0
# 447    7-1   245.0                  0   1175880.0
# 448    6-8   226.0             Butler  15409570.0
# 449    6-8   206.0               Duke   1348440.0
# 450    6-8   226.0                  0   2050000.0
# 451    6-6   206.0             Dayton    981348.0
# 452   6-10   234.0           Kentucky   2239800.0
# 453    6-3   203.0             Butler   2433333.0
# 454    6-1   179.0                  0    900000.0
# 455    7-3   256.0                  0   2900000.0
# 456    7-0   231.0             Kansas    947276.0
# 457      0     0.0                  0         0.0
#
# [458 rows x 9 columns]

# %%
nba["Salary"].fillna(0, inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba["College"].fillna("No College", inplace = True)

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        0.0
# 3      Georgia State  1148640.0
# 4         No College  5000000.0

# %% [markdown]
# ## The `.astype()` Method

# %%
nba = pd.read_csv("data/nba.csv").dropna(how = "all")
nba["Salary"].fillna(0, inplace = True)
nba["College"].fillna("None", inplace = True)
nba.head(6)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         0.0
# 3      Georgia State   1148640.0
# 4               None   5000000.0
# 5               None  12000000.0

# %%
nba.dtypes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
nba["Salary"] = nba["Salary"].astype("int")

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Number"] = nba["Number"].astype("int")
nba["Age"] = nba["Age"].astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Age"].astype("float")
# Out:
# 0      25.0
# 1      25.0
# 2      27.0
# 3      22.0
# 4      29.0
# 5      29.0
# 6      21.0
# 7      25.0
# 8      22.0
# 9      22.0
# 10     24.0
# 11     27.0
# 12     27.0
# 13     20.0
# 14     26.0
# 15     27.0
# 16     24.0
# 17     28.0
# 18     21.0
# 19     32.0
# 20     22.0
# 21     26.0
# 22     23.0
# 23     28.0
# 24     21.0
# 25     26.0
# 26     25.0
# 27     26.0
# 28     28.0
# 29     27.0
#        ...
# 427    20.0
# 428    25.0
# 429    23.0
# 430    24.0
# 431    27.0
# 432    23.0
# 433    28.0
# 434    34.0
# 435    24.0
# 436    25.0
# 437    24.0
# 438    23.0
# 439    26.0
# 440    30.0
# 441    20.0
# 442    28.0
# 443    23.0
# 444    24.0
# 445    20.0
# 446    24.0
# 447    23.0
# 448    26.0
# 449    23.0
# 450    28.0
# 451    26.0
# 452    20.0
# 453    26.0
# 454    24.0
# 455    26.0
# 456    26.0
# Name: Age, Length: 457, dtype: float64

# %%
nba["Position"].nunique()
# Out:
# 5

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba["Team"] = nba["Team"].astype("category")

# %%
nba.head()
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
# 3    R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics       8       PF   29   6-10   231.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0
# 3      Georgia State  1148640
# 4               None  5000000

# %% [markdown]
# ## Sort a `DataFrame` with the `.sort_values()` Method, Part I

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position  Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1    Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 2   John Holland  Boston Celtics      30       SG   27    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba.sort_values("Name", ascending = False)

nba.sort_values("Age", ascending = False)

nba.sort_values("Salary", ascending = False, inplace = True)
nba.head(3)
# Out:
#                 Name                 Team  Number Position  Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers      24       SF   37    6-6
# 169     LeBron James  Cleveland Cavaliers      23       SF   31    6-8
# 33   Carmelo Anthony      New York Knicks       7       SF   32    6-8
#
#      Weight   College    Salary
# 109   212.0      None  25000000
# 169   250.0      None  22970500
# 33    240.0  Syracuse  22875000

# %%
nba.sort_values("Salary", ascending = False, na_position = "first").tail()
# Out:
#                Name                    Team  Number Position  Age Height  \
# 353   Dorell Wright              Miami Heat      11       SF   30    6-9
# 264   Jordan Farmar       Memphis Grizzlies       4       PG   29    6-2
# 409      Greg Smith  Minnesota Timberwolves       4       PF   25   6-10
# 273  Alex Stepheson       Memphis Grizzlies      35       PF   28   6-10
# 270  Xavier Munford       Memphis Grizzlies      14       PG   24    6-3
#
#      Weight       College  Salary
# 353   205.0          None       0
# 264   180.0          UCLA       0
# 409   250.0  Fresno State       0
# 273   270.0           USC       0
# 270   180.0  Rhode Island       0

# %% [markdown]
# ## Sort a `DataFrame` with the `.sort_values()` Method, Part II

# %%
nba.head(3)
# Out:
#                 Name                 Team  Number Position  Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers      24       SF   37    6-6
# 169     LeBron James  Cleveland Cavaliers      23       SF   31    6-8
# 33   Carmelo Anthony      New York Knicks       7       SF   32    6-8
#
#      Weight   College    Salary
# 109   212.0      None  25000000
# 169   250.0      None  22970500
# 33    240.0  Syracuse  22875000

# %%
nba.sort_values(["Team", "Name"], ascending = [True, False], inplace = True)
nba.head(3)
# Out:
#                  Name           Team  Number Position  Age Height  Weight  \
# 322    Walter Tavares  Atlanta Hawks      22        C   24    7-3   260.0
# 310  Tim Hardaway Jr.  Atlanta Hawks      10       SG   24    6-6   205.0
# 321    Tiago Splitter  Atlanta Hawks      11        C   31   6-11   245.0
#
#       College   Salary
# 322      None  1000000
# 310  Michigan  1304520
# 321      None  9756250

# %% [markdown]
# ## Sort `DataFrame` with the `.sort_index()` Method

# %%
nba = pd.read_csv("data/nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values(["Number", "Salary", "Name"], inplace = True)
nba.tail(3)
# Out:
#                Name             Team  Number Position   Age Height  Weight  \
# 68   Lucas Nogueira  Toronto Raptors    92.0        C  23.0    7-0   220.0
# 1       Jae Crowder   Boston Celtics    99.0       SF  25.0    6-6   235.0
# 457             NaN              NaN     NaN      NaN   NaN    NaN     NaN
#
#        College     Salary
# 68         NaN  1842000.0
# 1    Marquette  6796117.0
# 457        NaN        NaN

# %%
nba.sort_index(ascending = False, inplace = True)

# %%
nba.head(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
#
#         Salary
# 457        NaN
# 456   947276.0
# 455  2900000.0

# %% [markdown]
# ## Rank Values with the `.rank()` Method

# %%
nba = pd.read_csv("data/nba.csv").dropna(how = "all")
nba["Salary"] = nba["Salary"].fillna(0).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary
# 0              Texas  7730337
# 1          Marquette  6796117
# 2  Boston University        0

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending = False).astype("int")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College   Salary  Salary Rank
# 0              Texas  7730337           97
# 1          Marquette  6796117          110
# 2  Boston University        0          452

# %%
nba.sort_values(by = "Salary", ascending = False)
# Out:
#                        Name                    Team  Number Position   Age  \
# 109             Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0
# 169            LeBron James     Cleveland Cavaliers    23.0       SF  31.0
# 33          Carmelo Anthony         New York Knicks     7.0       SF  32.0
# 251           Dwight Howard         Houston Rockets    12.0        C  30.0
# 339              Chris Bosh              Miami Heat     1.0       PF  32.0
# 100              Chris Paul    Los Angeles Clippers     3.0       PG  31.0
# 414            Kevin Durant   Oklahoma City Thunder    35.0       SF  27.0
# 164            Derrick Rose           Chicago Bulls     1.0       PG  27.0
# 349             Dwyane Wade              Miami Heat     3.0       SG  34.0
# 174              Kevin Love     Cleveland Cavaliers     0.0       PF  27.0
# 98           DeAndre Jordan    Los Angeles Clippers     6.0        C  27.0
# 23              Brook Lopez           Brooklyn Nets    11.0        C  28.0
# 294       LaMarcus Aldridge       San Antonio Spurs    12.0       PF  30.0
# 265              Marc Gasol       Memphis Grizzlies    33.0        C  31.0
# 96            Blake Griffin    Los Angeles Clippers    32.0       PF  27.0
# 315            Paul Millsap           Atlanta Hawks     4.0       PF  31.0
# 199             Paul George          Indiana Pacers    13.0       SF  26.0
# 426       Russell Westbrook   Oklahoma City Thunder     0.0       PG  27.0
# 168            Kyrie Irving     Cleveland Cavaliers     2.0       PG  24.0
# 233         Wesley Matthews        Dallas Mavericks    23.0       SG  29.0
# 301           Kawhi Leonard       San Antonio Spurs     2.0       SF  24.0
# 418             Enes Kanter   Oklahoma City Thunder    11.0        C  24.0
# 153            Jimmy Butler           Chicago Bulls    21.0       SG  26.0
# 220             Greg Monroe         Milwaukee Bucks    15.0        C  26.0
# 189           Tobias Harris         Detroit Pistons    34.0       SF  23.0
# 382               John Wall      Washington Wizards     2.0       PG  25.0
# 143        DeMarcus Cousins        Sacramento Kings    15.0        C  25.0
# 249            James Harden         Houston Rockets    13.0       SG  26.0
# 111             Roy Hibbert      Los Angeles Lakers    17.0        C  29.0
# 288             Eric Gordon    New Orleans Pelicans    10.0       SG  27.0
# 301    6-7   230.0        San Diego State  16407500           22
# 418   6-11   245.0               Kentucky  16407500           22
# 153    6-7   220.0              Marquette  16407500           22
# 220   6-11   265.0             Georgetown  16407500           22
# 189    6-9   235.0              Tennessee  16000000           25
# 382    6-4   195.0               Kentucky  15851950           26
# 143   6-11   270.0               Kentucky  15851950           26
# 249    6-5   220.0          Arizona State  15756438           28
# 111    7-2   270.0             Georgetown  15592217           29
# 288    6-4   215.0                Indiana  15514031           30
# ..     ...     ...                    ...       ...          ...
# 304    6-3   200.0                   Utah    250750          428
# 73    6-11   250.0                  Rider    245177          429
# 420   6-10   250.0               Kentucky    222888          430
# 203   5-11   195.0         North Carolina    211744          431
# 123    6-7   209.0                Arizona    206192          432
# 248    6-3   200.0             Charleston    200600          434
# 381    6-4   205.0                    LSU    200600          434
# 303    6-7   199.0       Western Carolina    200600          434
# 326    6-3   189.0             California    189455          436
# 282    6-6   203.0             Iowa State    169883          437
# 45     6-6   205.0             Washington    167406          438
# 21     6-4   219.0             Cincinnati    134215          439
# 92     6-9   250.0          Arizona State    111444          440
# 184    6-5   189.0   North Carolina State    111444          440
# 175    6-5   179.0              Tennessee    111196          442
# 135    6-8   260.0       UC Santa Barbara     83397          443
# 130   5-11   175.0               Missouri     55722          444
# 291    6-5   220.0       UC Santa Barbara     55722          444
# 32     6-7   205.0                    NaN     30888          446
# 350    6-2   165.0  Virginia Commonwealth         0          452
# 46     6-9   254.0                   Duke         0          452
# 2      6-5   205.0      Boston University         0          452
# 171    6-6   225.0                   Duke         0          452
# 397    6-7   210.0                    NaN         0          452
# 269    6-3   190.0                Detroit         0          452
# 353    6-9   205.0                    NaN         0          452
# 264    6-2   180.0                   UCLA         0          452
# 409   6-10   250.0           Fresno State         0          452
# 273   6-10   270.0                    USC         0          452
# 270    6-3   180.0           Rhode Island         0          452
#
# [457 rows x 10 columns]

# %%
df = pd.read_csv("data/employees.csv")
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %% [markdown]
# ## Filter A `DataFrame` Based On A Condition

# %%
df = pd.read_csv("data/employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-06-08 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-06-08 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-06-08 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# ## Filter with More than One Condition (AND)

# %%
mask1 = df["Gender"] == "Male"
mask2 = df["Team"] == "Marketing"

df[mask1 & mask2]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-06-08 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2020-06-08 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2020-06-08 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2020-06-08 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2020-06-08 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2020-06-08 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2020-06-08 07:01:00   80740   19.305
# 965  Catherine  Female 1989-09-25 2020-06-08 01:31:00   68164   18.393
# 966      Louis    Male 2011-08-16 2020-06-08 17:19:00   93022    9.146
# 969      Linda  Female 2010-02-04 2020-06-08 20:49:00   44486   17.308
# 970      Alice  Female 1988-09-03 2020-06-08 20:54:00   63571   15.397
# 971    Patrick    Male 2002-12-30 2020-06-08 02:01:00   75423    5.368
# 972     Victor     NaN 2006-07-28 2020-06-08 14:49:00   76381   11.159
# 974      Harry    Male 2011-08-30 2020-06-08 18:31:00   67656   16.455
# 976     Denise  Female 1992-10-19 2020-06-08 05:42:00  137954    4.195
# 978       Sean    Male 1983-01-17 2020-06-08 14:23:00   66146   11.178
# 979     Ernest    Male 2013-07-20 2020-06-08 06:41:00  142935   13.198
# 980   Kimberly  Female 2013-01-26 2020-06-08 00:57:00   46233    8.862
# 982       Rose  Female 1982-04-06 2020-06-08 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2020-06-08 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2020-06-08 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2020-06-08 07:04:00   82871   17.999
# 987     Gloria  Female 2014-12-08 2020-06-08 05:08:00  136709   10.331
# 990      Robin  Female 1987-07-24 2020-06-08 13:35:00  100765   10.982
# 991       Rose  Female 2002-08-25 2020-06-08 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-06-08 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-06-08 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2020-06-08 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-06-08 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2020-06-08 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# 6                 True               Product
# 7                 True               Finance
# 8                 True           Engineering
# 9                 True  Business Development
# 10                True                   NaN
# 11                True                 Legal
# 12                True       Human Resources
# 14                True               Finance
# 17               False               Product
# 18               False       Client Services
# 20                True                 Legal
# 22                True       Client Services
# 23                True                   NaN
# 25                True       Client Services
# 26                True             Marketing
# 28                True       Client Services
# 29                True                 Legal
# 30                True           Engineering
# 32                True                   NaN
# 37                True       Client Services
# 38                True  Business Development
# 39                True       Client Services
# 40                True          Distribution
# 41                True  Business Development
# 43                True             Marketing
# ..                 ...                   ...
# 957               True                 Sales
# 958              False           Engineering
# 959               True  Business Development
# 960               True  Business Development
# 961              False                 Legal
# 963               True                 Sales
# 964               True                 Sales
# 965              False       Client Services
# 966               True       Human Resources
# 969               True           Engineering
# 970               True               Product
# 971               True  Business Development
# 972               True                 Sales
# 974               True       Client Services
# 976               True                 Legal
# 978              False       Human Resources
# 979               True               Product
# 980               True           Engineering
# 982               True       Human Resources
# 983              False           Engineering
# 985              False                 Legal
# 986              False             Marketing
# 987               True               Finance
# 990               True       Client Services
# 991               True             Marketing
# 992               True               Finance
# 993               True           Engineering
# 994               True             Marketing
# 996              False               Finance
# 999               True                 Sales
#
# [653 rows x 8 columns]

# %%
mask1 = df["First Name"] == "Robert"
mask2 = df["Team"] == "Client Services"
mask3 = df["Start Date"] > "2016-06-01"

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2020-06-08 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2020-06-08 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2020-06-08 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2020-06-08 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# ## The `.isin()` Method

# %%
mask1 = df["Team"] == "Legal"
mask2 = df["Team"] == "Sales"
mask3 = df["Team"] == "Product"

df[mask1 | mask2 | mask3]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 
#
#      Senior Management Team
# 1                 True  NaN
# 10                True  NaN
# 23                True  NaN
# 32                True  NaN
# 91               False  NaN
# 109              False  NaN
# 139               True  NaN
# 199               True  NaN
# 258              False  NaN
# 290               True  NaN
# 314              False  NaN
# 367               True  NaN
# 382               True  NaN
# 434               True  NaN
# 438               True  NaN
# 445              False  NaN
# 479               True  NaN
# 512              False  NaN
# 513              False  NaN
# 520               True  NaN
# 567               True  NaN
# 573               True  NaN
# 580              False  NaN
# 626               True  NaN
# 634              False  NaN
# 635               True  NaN
# 647              False  NaN
# 669               True  NaN
# 684              False  NaN
# 706               True  NaN
# 726               True  NaN
# 753               True  NaN
# 774               True  NaN
# 781              False  NaN
# 794              False  NaN
# 826               True  NaN
# 850              False  NaN
# 851               True  NaN
# 853               True  NaN
# 855               True  NaN
# 864              False  NaN
# 912              False  NaN
# 951               True  NaN

# %%
condition = df["Gender"].notnull()

df[condition]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-06-08 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-06-08 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-06-08 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-06-08 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-06-08 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-06-08 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-06-08 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2020-06-08 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2020-06-08 06:29:00   95570   18.523
# 9      Frances  Female 2002-08-08 2020-06-08 06:51:00  139852    7.524
# 10      Louise  Female 1980-08-12 2020-06-08 09:01:00   63241   15.132
# 11       Julie  Female 1997-10-26 2020-06-08 15:19:00  102508   12.637
# 12     Brandon    Male 1980-12-01 2020-06-08 01:08:00  112807   17.492
# 13        Gary    Male 2008-01-27 2020-06-08 23:40:00  109831    5.831
# 14    Kimberly  Female 1999-01-14 2020-06-08 07:13:00   41426   14.543
# 15     Lillian  Female 2016-06-05 2020-06-08 06:09:00   59414    1.256
# 16      Jeremy    Male 2010-09-21 2020-06-08 05:56:00   90370    7.369
# 17       Shawn    Male 1986-12-07 2020-06-08 19:45:00  111737    6.414
# 18       Diana  Female 1981-10-23 2020-06-08 10:27:00  132940   19.082
# 19       Donna  Female 2010-07-22 2020-06-08 03:48:00   81014    1.894
# 21     Matthew    Male 1995-09-05 2020-06-08 02:12:00  100612   13.645
# 23         NaN    Male 2012-06-14 2020-06-08 16:19:00  125792    5.042
# 24        John    Male 1992-07-01 2020-06-08 22:08:00   97950   13.873
# 25         NaN    Male 2012-10-08 2020-06-08 01:12:00   37076   18.576
# 26       Craig    Male 2000-02-27 2020-06-08 07:45:00   37598    7.757
# 28       Terry    Male 1981-11-27 2020-06-08 18:30:00  124008   13.464
# 29    Benjamin    Male 2005-01-26 2020-06-08 22:06:00   79529    7.008
# 30   Christina  Female 2002-08-06 2020-06-08 13:19:00  118780    9.096
# 32         NaN    Male 1998-08-21 2020-06-08 14:27:00  122340    6.417
# 33        Jean  Female 1993-12-18 2020-06-08 09:07:00  119082   16.180
# 903               True       Human Resources
# 906              False                 Sales
# 907              False               Finance
# 912              False                   NaN
# 919              False          Distribution
# 922               True  Business Development
# 927               True  Business Development
# 932               True       Client Services
# 940               True          Distribution
# 941               True           Engineering
# 943              False           Engineering
# 950              False  Business Development
# 963               True                 Sales
# 977              False               Product
# 982               True       Human Resources
# 988              False       Human Resources
# 992               True               Finance
#
# [136 rows x 8 columns]

# %% [markdown]
# ## The `.duplicated()` Method

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-06-08 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-06-08 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-06-08 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask = ~df["First Name"].duplicated(keep = False)
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2020-06-08 01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22 2020-06-08 06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18 2020-06-08 09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19 2020-06-08 03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11 2020-06-08 10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24 2020-06-08 10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07 2020-06-08 22:47:00   93901   17.821
# 832      Keith    Male 2003-02-12 2020-06-08 15:02:00  120672   19.467
# 887      David    Male 2009-12-05 2020-06-08 08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# 291               True       Client Services
# 495              False                 Sales
# 688               True                 Legal
# 832              False                 Legal
# 887              False                 Legal

# %% [markdown]
# ## The `.drop_duplicates()` Method

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-06-08 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-06-08 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-06-08 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %%
df.drop_duplicates(subset = ["First Name"], keep = False)
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2020-06-08 01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22 2020-06-08 06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18 2020-06-08 09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19 2020-06-08 03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11 2020-06-08 10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24 2020-06-08 10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07 2020-06-08 22:47:00   93901   17.821
# 832      Keith    Male 2003-02-12 2020-06-08 15:02:00  120672   19.467
# 887      David    Male 2009-12-05 2020-06-08 08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# 291               True       Client Services
# 495              False                 Sales
# 688               True                 Legal
# 832              False                 Legal
# 887              False                 Legal

# %%
df.drop_duplicates(subset = ["First Name", "Team"], inplace = True)

# %%
df.head(2)
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male 1993-08-06 2020-06-08 12:42:00   97308    6.945
# 1     Thomas   Male 1996-03-31 2020-06-08 06:53:00   61933    4.170
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN

# %%
len(df)
# Out:
# 769

# %% [markdown]
# ## The `.unique()` and `.nunique()` Methods

# %%
df = pd.read_csv("data/employees.csv", parse_dates = ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-06-08 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-06-08 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-06-08 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df["Gender"].unique()

df["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
len(df["Team"].unique())
# Out:
# 11

# %%
df["Team"].nunique(dropna = False)
# Out:
# 11

# %%
bond = pd.read_csv("data/jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %% [markdown]
# ## The `.set_index()` and `.reset_index()` Methods

# %%
bond.set_index("Film", inplace = True)
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(drop = False, inplace = True)
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index("Film", inplace = True)
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(inplace = True)
bond.set_index("Year", inplace = True)
bond.head(3)
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2

# %% [markdown]
# ## Retrieve Rows by Index Label with `.loc[]`

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Goldfinger"]
bond.loc["GoldenEye"]
#bond.loc["Sacred Bond"]
bond.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc["Diamonds Are Forever" : "Moonraker"]
bond.loc[: "On Her Majesty's Secret Service"]
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# Moonraker                        1979     Roger Moore    Lewis Gilbert
# Never Say Never Again            1983    Sean Connery   Irvin Kershner
# Octopussy                        1983     Roger Moore        John Glen
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6

# %%
bond.loc[["Octopussy", "Moonraker"]]
# Out:
#            Year        Actor       Director  Box Office  Budget  \
# Film
# Octopussy  1983  Roger Moore      John Glen       373.8    53.9
# Moonraker  1979  Roger Moore  Lewis Gilbert       535.0    91.5
#
#            Bond Actor Salary
# Film
# Octopussy                7.8
# Moonraker                NaN

# %%
bond.loc[["For Your Eyes Only", "Live and Let Die", "Gold Bond"]]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                       Year        Actor      Director  Box Office  Budget  \
# Film
# For Your Eyes Only  1981.0  Roger Moore     John Glen       449.4    60.2
# Live and Let Die    1973.0  Roger Moore  Guy Hamilton       460.3    30.8
# Gold Bond              NaN          NaN           NaN         NaN     NaN
#
#                     Bond Actor Salary
# Film
# For Your Eyes Only                NaN
# Live and Let Die                  NaN
# Gold Bond                         NaN

# %%
"Gold Bond" in bond.index
# Out:
# False

# %% [markdown]
# ## Retrieve Row(s) by Index Position with `iloc`

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
# bond.loc[15]
bond.iloc[15]
# Out:
# Year                           1969
# Actor                George Lazenby
# Director              Peter R. Hunt
# Box Office                    291.5
# Budget                         37.3
# Bond Actor Salary               0.6
# Name: On Her Majesty's Secret Service, dtype: object

# %%
bond.iloc[[15, 20]]
bond.iloc[:4]
bond.iloc[4:8]
bond.iloc[20:]
# Out:
#                              Year           Actor            Director  \
# Film
# The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me         1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough      1999  Pierce Brosnan       Michael Apted
# Thunderball                  1965    Sean Connery       Terence Young
# Tomorrow Never Dies          1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice          1967    Sean Connery       Lewis Gilbert
#
#                              Box Office  Budget  Bond Actor Salary
# Film
# The Man with the Golden Gun       334.0    27.7                NaN
# The Spy Who Loved Me              533.0    45.1                NaN
# The World Is Not Enough           439.5   158.3               13.5
# Thunderball                       848.1    41.9                4.7
# Tomorrow Never Dies               463.2   133.9               10.0
# You Only Live Twice               514.2    59.9                4.4

# %%
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.iloc[[5, 10, 15, 20]]
# Out:
#                                  Year           Actor       Director  \
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# Licence to Kill                  1989  Timothy Dalton      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Man with the Golden Gun      1974     Roger Moore   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Man with the Golden Gun           334.0    27.7                NaN

# %% [markdown]
# ## The Catch-All `.ix[]` Method

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                      275.2    54.5                9.1
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                    449.4    60.2                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Live and Let Die                      460.3    30.8                NaN
# Moonraker                             535.0    91.5                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                             373.8    53.9                7.8
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The Man with the Golden Gun           334.0    27.7                NaN
# The Spy Who Loved Me                  533.0    45.1                NaN
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.ix["GoldenEye"]
bond.ix[["Diamonds Are Forever", "Moonraker", "Spectre"]]
bond.ix["A View to a Kill" : "The World Is Not Enough"]
# bond.ix["Sacred Bond"]
# bond.ix[["Spectre", "Sacred Bond"]]

"Spectre" in bond.index
"Sacred Bond" in bond.index
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# False

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Moonraker", ["Actor", "Budget", "Year"]]
# Out:
# Actor     Roger Moore
# Budget           91.5
# Year             1979
# Name: Moonraker, dtype: object

# %%
bond.iloc[14, [5, 3, 2]]
# Out:
# Bond Actor Salary          7.8
# Box Office               373.8
# Director             John Glen
# Name: Octopussy, dtype: object

# %%
bond.ix[20, "Budget"]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 27.7

# %%
bond.ix["The Man with the Golden Gun", :4]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                  1974
# Actor          Roger Moore
# Director      Guy Hamilton
# Box Office             334
# Name: The Man with the Golden Gun, dtype: object

# %%
bond.ix[5, 3]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 448.8

# %% [markdown]
# ## Set New Values for a Specific Cell or Row

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.ix["Dr. No"]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Year                          1962
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                           7
# Bond Actor Salary              0.6
# Name: Dr. No, dtype: object

# %%
bond.ix["Dr. No", "Actor"] = "Sir Sean Connery"
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bond.ix["Dr. No", ["Box Office", "Budget", "Bond Actor Salary"]] = [448800000, 7000000, 600000]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bond.ix["Dr. No", "Budget"]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 7000000.0

# %% [markdown]
# ## Set Multiple Values in `DataFrame`

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
mask = bond["Actor"] == "Sean Connery"

# %%
bond.ix[mask, "Actor"] = "Sir Sean Connery"
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
bond[bond["Actor"] == "Roger Moore"]

bond.ix[bond["Actor"] == "Roger Moore"]
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
#                              Year        Actor       Director  Box Office  \
# Film
# A View to a Kill             1985  Roger Moore      John Glen       275.2
# For Your Eyes Only           1981  Roger Moore      John Glen       449.4
# Live and Let Die             1973  Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979  Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983  Roger Moore      John Glen       373.8
# The Man with the Golden Gun  1974  Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977  Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond Actor Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# Live and Let Die               30.8                NaN
# Moonraker                      91.5                NaN
# Octopussy                      53.9                7.8
# The Man with the Golden Gun    27.7                NaN
# The Spy Who Loved Me           45.1                NaN

# %% [markdown]
# ## Rename Index Labels or Columns in a `DataFrame`

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.rename(columns = {"Year" : "Release Date", "Box Office" : "Revenue"}, inplace = True)

# %%
bond.head(1)
# Out:
#                   Release Date        Actor   Director  Revenue  Budget  \
# Film
# A View to a Kill          1985  Roger Moore  John Glen    275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.rename(index = {"Dr. No" : "Doctor No", 
                     "GoldenEye" : "Golden Eye",
                    "The World Is Not Enough" : "Best Bond Movie Ever"}, inplace = True)

# %%
bond.loc["Best Bond Movie Ever"]
# Out:
# Release Date                   1999
# Actor                Pierce Brosnan
# Director              Michael Apted
# Revenue                       439.5
# Budget                        158.3
# Bond Actor Salary              13.5
# Name: Best Bond Movie Ever, dtype: object

# %%
bond.head(1)
# Out:
#                   Release Date        Actor   Director  Revenue  Budget  \
# Film
# A View to a Kill          1985  Roger Moore  John Glen    275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.columns = ["Year of Release", "Actor", "Director", "Gross", "Cost", "Salary"]

# %%
bond.head(3)
# Out:
#                   Year of Release         Actor         Director  Gross  \
# Film
# A View to a Kill             1985   Roger Moore        John Glen  275.2
# Casino Royale                2006  Daniel Craig  Martin Campbell  581.5
# Casino Royale                1967   David Niven       Ken Hughes  315.0
#
#                    Cost  Salary
# Film
# A View to a Kill   54.5     9.1
# Casino Royale     145.3     3.3
# Casino Royale      85.0     NaN

# %% [markdown]
# ## Delete Rows or Columns from a `DataFrame`

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
# bond.drop("Casino Royale", inplace = True)
bond.drop(labels = ["Box Office", "Bond Actor Salary", "Actor"], axis = "columns", inplace = True)

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
actor = bond.pop("Actor")

# %%
actor
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# The Living Daylights               Timothy Dalton
# The Man with the Golden Gun           Roger Moore
# The Spy Who Loved Me                  Roger Moore
# The World Is Not Enough            Pierce Brosnan
# Thunderball                          Sean Connery
# Tomorrow Never Dies                Pierce Brosnan
# You Only Live Twice                  Sean Connery
# Name: Actor, dtype: object

# %%
del bond["Director"]

# %%
del bond["Year"]

# %%
bond.head()
# Out:
#                       Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill           275.2    54.5                9.1
# Casino Royale              581.5   145.3                3.3
# Casino Royale              315.0    85.0                NaN
# Diamonds Are Forever       442.5    34.7                5.8
# Die Another Day            465.4   154.2               17.9

# %% [markdown]
# ## Create Random Sample

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sample(n = 4, axis = "columns")
# Out:
#                                           Actor  Bond Actor Salary  Year  \
# Film
# A View to a Kill                    Roger Moore                9.1  1985
# Casino Royale                      Daniel Craig                3.3  2006
# Casino Royale                       David Niven                NaN  1967
# Diamonds Are Forever               Sean Connery                5.8  1971
# Die Another Day                  Pierce Brosnan               17.9  2002
# Dr. No                             Sean Connery                0.6  1962
# For Your Eyes Only                  Roger Moore                NaN  1981
# From Russia with Love              Sean Connery                1.6  1963
# GoldenEye                        Pierce Brosnan                5.1  1995
# Goldfinger                         Sean Connery                3.2  1964
# Licence to Kill                  Timothy Dalton                7.9  1989
# Live and Let Die                    Roger Moore                NaN  1973
# Moonraker                           Roger Moore                NaN  1979
# Never Say Never Again              Sean Connery                NaN  1983
# Octopussy                           Roger Moore                7.8  1983
# On Her Majesty's Secret Service  George Lazenby                0.6  1969
# Quantum of Solace                  Daniel Craig                8.1  2008
# Skyfall                            Daniel Craig               14.5  2012
# Spectre                            Daniel Craig                NaN  2015
# The Living Daylights             Timothy Dalton                5.2  1987
# The Man with the Golden Gun         Roger Moore                NaN  1974
# The Spy Who Loved Me                Roger Moore                NaN  1977
# The World Is Not Enough          Pierce Brosnan               13.5  1999
# Thunderball                        Sean Connery                4.7  1965
# Tomorrow Never Dies              Pierce Brosnan               10.0  1997
# You Only Live Twice                Sean Connery                4.4  1967
#
#                                  Budget
# Film
# A View to a Kill                   54.5
# Casino Royale                     145.3
# Casino Royale                      85.0
# Diamonds Are Forever               34.7
# Die Another Day                   154.2
# Dr. No                              7.0
# For Your Eyes Only                 60.2
# From Russia with Love              12.6
# GoldenEye                          76.9
# Goldfinger                         18.6
# Licence to Kill                    56.7
# Live and Let Die                   30.8
# Moonraker                          91.5
# Never Say Never Again              86.0
# Octopussy                          53.9
# On Her Majesty's Secret Service    37.3
# Quantum of Solace                 181.4
# Skyfall                           170.2
# Spectre                           206.3
# The Living Daylights               68.8
# The Man with the Golden Gun        27.7
# The Spy Who Loved Me               45.1
# The World Is Not Enough           158.3
# Thunderball                        41.9
# Tomorrow Never Dies               133.9
# You Only Live Twice                59.9

# %% [markdown]
# ## The `.nsmallest()` and `.nlargest()` Methods

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sort_values("Box Office", ascending = False).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(3, columns = "Box Office")

bond.nsmallest(n = 2, columns = "Box Office")
# Out:
#                   Year           Actor   Director  Box Office  Budget  \
# Film
# Licence to Kill   1989  Timothy Dalton  John Glen       250.9    56.7
# A View to a Kill  1985     Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# Licence to Kill                 7.9
# A View to a Kill                9.1

# %%
bond.nlargest(3, columns = "Budget")

bond.nsmallest(n = 6, columns = "Bond Actor Salary")
# Out:
#                                  Year           Actor         Director  \
# Film
# Dr. No                           1962    Sean Connery    Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# From Russia with Love            1963    Sean Connery    Terence Young
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# You Only Live Twice              1967    Sean Connery    Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# On Her Majesty's Secret Service       291.5    37.3                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Casino Royale                         581.5   145.3                3.3
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond["Box Office"].nlargest(8)

bond["Year"].nsmallest(2)
# Out:
# Film
# Dr. No                   1962
# From Russia with Love    1963
# Name: Year, dtype: int64

# %% [markdown]
# ## Filtering with the `where` Method

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
mask = bond["Actor"] == "Sean Connery"
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# Moonraker                           NaN           NaN             NaN
# Never Say Never Again            1983.0  Sean Connery  Irvin Kershner
# Octopussy                           NaN           NaN             NaN
# On Her Majesty's Secret Service     NaN           NaN             NaN
# Quantum of Solace                   NaN           NaN             NaN
# Skyfall                             NaN           NaN             NaN
# Spectre                             NaN           NaN             NaN
# The Living Daylights                NaN           NaN             NaN
# The Man with the Golden Gun         NaN           NaN             NaN
# The Spy Who Loved Me                NaN           NaN             NaN
# The World Is Not Enough             NaN           NaN             NaN
# Thunderball                      1965.0  Sean Connery   Terence Young
# Tomorrow Never Dies                 NaN           NaN             NaN
# You Only Live Twice              1967.0  Sean Connery   Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                        NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                         NaN     NaN                NaN
# Dr. No                                448.8     7.0                0.6
# For Your Eyes Only                      NaN     NaN                NaN
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                               NaN     NaN                NaN
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                         NaN     NaN                NaN
# Live and Let Die                        NaN     NaN                NaN
# Moonraker                               NaN     NaN                NaN
# Never Say Never Again                 380.0    86.0                NaN
# Octopussy                               NaN     NaN                NaN
# On Her Majesty's Secret Service         NaN     NaN                NaN
# Quantum of Solace                       NaN     NaN                NaN
# Skyfall                                 NaN     NaN                NaN
# Spectre                                 NaN     NaN                NaN
# The Living Daylights                    NaN     NaN                NaN
# The Man with the Golden Gun             NaN     NaN                NaN
# The Spy Who Loved Me                    NaN     NaN                NaN
# The World Is Not Enough                 NaN     NaN                NaN
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                     NaN     NaN                NaN
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.where(bond["Box Office"] > 800)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# Moonraker                           NaN           NaN            NaN
# Never Say Never Again               NaN           NaN            NaN
# Octopussy                           NaN           NaN            NaN
# On Her Majesty's Secret Service     NaN           NaN            NaN
# Quantum of Solace                   NaN           NaN            NaN
# Skyfall                          2012.0  Daniel Craig     Sam Mendes
# Spectre                             NaN           NaN            NaN
# The Living Daylights                NaN           NaN            NaN
# The Man with the Golden Gun         NaN           NaN            NaN
# The Spy Who Loved Me                NaN           NaN            NaN
# The World Is Not Enough             NaN           NaN            NaN
# Thunderball                      1965.0  Sean Connery  Terence Young
# Tomorrow Never Dies                 NaN           NaN            NaN
# You Only Live Twice                 NaN           NaN            NaN
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                        NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Diamonds Are Forever                    NaN     NaN                NaN
# Die Another Day                         NaN     NaN                NaN
# Dr. No                                  NaN     NaN                NaN
# For Your Eyes Only                      NaN     NaN                NaN
# From Russia with Love                   NaN     NaN                NaN
# GoldenEye                               NaN     NaN                NaN
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                         NaN     NaN                NaN
# Live and Let Die                        NaN     NaN                NaN
# Moonraker                               NaN     NaN                NaN
# Never Say Never Again                   NaN     NaN                NaN
# Octopussy                               NaN     NaN                NaN
# On Her Majesty's Secret Service         NaN     NaN                NaN
# Quantum of Solace                       NaN     NaN                NaN
# Skyfall                               943.5   170.2               14.5
# Spectre                                 NaN     NaN                NaN
# The Living Daylights                    NaN     NaN                NaN
# The Man with the Golden Gun             NaN     NaN                NaN
# The Spy Who Loved Me                    NaN     NaN                NaN
# The World Is Not Enough                 NaN     NaN                NaN
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                     NaN     NaN                NaN
# You Only Live Twice                     NaN     NaN                NaN

# %%
mask2 = bond["Box Office"] > 800

# %%
bond.where(mask & mask2)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# Moonraker                           NaN           NaN            NaN
# Never Say Never Again               NaN           NaN            NaN
# Octopussy                           NaN           NaN            NaN
# On Her Majesty's Secret Service     NaN           NaN            NaN
# Quantum of Solace                   NaN           NaN            NaN
# Skyfall                             NaN           NaN            NaN
# Spectre                             NaN           NaN            NaN
# The Living Daylights                NaN           NaN            NaN
# The Man with the Golden Gun         NaN           NaN            NaN
# The Spy Who Loved Me                NaN           NaN            NaN
# The World Is Not Enough             NaN           NaN            NaN
# Thunderball                      1965.0  Sean Connery  Terence Young
# Tomorrow Never Dies                 NaN           NaN            NaN
# You Only Live Twice                 NaN           NaN            NaN
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# A View to a Kill                        NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Casino Royale                           NaN     NaN                NaN
# Diamonds Are Forever                    NaN     NaN                NaN
# Die Another Day                         NaN     NaN                NaN
# Dr. No                                  NaN     NaN                NaN
# For Your Eyes Only                      NaN     NaN                NaN
# From Russia with Love                   NaN     NaN                NaN
# GoldenEye                               NaN     NaN                NaN
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                         NaN     NaN                NaN
# Live and Let Die                        NaN     NaN                NaN
# Moonraker                               NaN     NaN                NaN
# Never Say Never Again                   NaN     NaN                NaN
# Octopussy                               NaN     NaN                NaN
# On Her Majesty's Secret Service         NaN     NaN                NaN
# Quantum of Solace                       NaN     NaN                NaN
# Skyfall                                 NaN     NaN                NaN
# Spectre                                 NaN     NaN                NaN
# The Living Daylights                    NaN     NaN                NaN
# The Man with the Golden Gun             NaN     NaN                NaN
# The Spy Who Loved Me                    NaN     NaN                NaN
# The World Is Not Enough                 NaN     NaN                NaN
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                     NaN     NaN                NaN
# You Only Live Twice                     NaN     NaN                NaN

# %% [markdown]
# ## The `.query()` Method

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.columns = [column_name.replace(" ", "_") for column_name in bond.columns]
bond.head(1)
# Out:
#                   Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1

# %%
bond.query('Actor == "Sean Connery"')
bond.query("Director == 'Terence Young'")
bond.query("Actor != 'Roger Moore'")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Thunderball                      1965    Sean Connery       Terence Young
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Diamonds Are Forever                  442.5    34.7                5.8
# Die Another Day                       465.4   154.2               17.9
# Dr. No                                448.8     7.0                0.6
# From Russia with Love                 543.8    12.6                1.6
# GoldenEye                             518.5    76.9                5.1
# Goldfinger                            820.4    18.6                3.2
# Licence to Kill                       250.9    56.7                7.9
# Never Say Never Again                 380.0    86.0                NaN
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The World Is Not Enough               439.5   158.3               13.5
# Thunderball                           848.1    41.9                4.7
# Tomorrow Never Dies                   463.2   133.9               10.0
# You Only Live Twice                   514.2    59.9                4.4

# %%
bond.query("Box_Office > 600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor == 'Roger Moore' or Director == 'John Glen'")
# Out:
#                              Year           Actor       Director  Box_Office  \
# Film
# A View to a Kill             1985     Roger Moore      John Glen       275.2
# For Your Eyes Only           1981     Roger Moore      John Glen       449.4
# Licence to Kill              1989  Timothy Dalton      John Glen       250.9
# Live and Let Die             1973     Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979     Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983     Roger Moore      John Glen       373.8
# The Living Daylights         1987  Timothy Dalton      John Glen       313.5
# The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977     Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond_Actor_Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# Licence to Kill                56.7                7.9
# Live and Let Die               30.8                NaN
# Moonraker                      91.5                NaN
# Octopussy                      53.9                7.8
# The Living Daylights           68.8                5.2
# The Man with the Golden Gun    27.7                NaN
# The Spy Who Loved Me           45.1                NaN

# %%
bond.query("Actor in ['Timothy Dalton', 'George Lazenby']")

bond.query("Actor not in ['Sean Connery', 'Roger Moore']")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Licence to Kill                  1989  Timothy Dalton           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Casino Royale                         581.5   145.3                3.3
# Casino Royale                         315.0    85.0                NaN
# Die Another Day                       465.4   154.2               17.9
# GoldenEye                             518.5    76.9                5.1
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# Quantum of Solace                     514.2   181.4                8.1
# Skyfall                               943.5   170.2               14.5
# Spectre                               726.7   206.3                NaN
# The Living Daylights                  313.5    68.8                5.2
# The World Is Not Enough               439.5   158.3               13.5
# Tomorrow Never Dies                   463.2   133.9               10.0

# %% [markdown]
# ## A Review of the `.apply()` Method on Single Columns

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + " MILLIONS!"

# %%
columns = ["Box_Office", "Budget", "Bond_Actor_Salary"]
for col in columns:
    bond[col] = bond[col].apply(convert_to_string_and_add_millions)

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director       Box_Office  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen  275.2 MILLIONS!
# Casino Royale     2006  Daniel Craig  Martin Campbell  581.5 MILLIONS!
# Casino Royale     1967   David Niven       Ken Hughes  315.0 MILLIONS!
#
#                            Budget Bond_Actor_Salary
# Film
# A View to a Kill   54.5 MILLIONS!     9.1 MILLIONS!
# Casino Royale     145.3 MILLIONS!     3.3 MILLIONS!
# Casino Royale      85.0 MILLIONS!     nan MILLIONS!

# %% [markdown]
# ## The `.apply()` Method with Row Values

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
    
    actor = row[1]
    budget = row[4]
    
    if actor == "Pierce Brosnan":
        return "The best"
    elif (actor == "Roger Moore") and (budget > 40):
        return "Enjoyable"
    else:
        return "I have no clue"
    
bond.apply(good_movie, axis = "columns")
# Out:
# Film
# A View to a Kill                        Enjoyable
# Casino Royale                      I have no clue
# Casino Royale                      I have no clue
# Diamonds Are Forever               I have no clue
# Die Another Day                          The best
# Dr. No                             I have no clue
# For Your Eyes Only                      Enjoyable
# From Russia with Love              I have no clue
# GoldenEye                                The best
# Goldfinger                         I have no clue
# Licence to Kill                    I have no clue
# Live and Let Die                   I have no clue
# Moonraker                               Enjoyable
# Never Say Never Again              I have no clue
# Octopussy                               Enjoyable
# On Her Majesty's Secret Service    I have no clue
# Quantum of Solace                  I have no clue
# Skyfall                            I have no clue
# Spectre                            I have no clue
# The Living Daylights               I have no clue
# The Man with the Golden Gun        I have no clue
# The Spy Who Loved Me                    Enjoyable
# The World Is Not Enough                  The best
# Thunderball                        I have no clue
# Tomorrow Never Dies                      The best
# You Only Live Twice                I have no clue
# dtype: object

# %% [markdown]
# ## The `.copy()` Method

# %%
bond = pd.read_csv("data/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond["Director"]
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors["A View to a Kill"] = "Mister John Glen"
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor          Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore  Mister John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig   Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven        Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond["Director"].copy()
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
directors["A View to a Kill"] = "Mister John Glen"

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor          Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore  Mister John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig   Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven        Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN
